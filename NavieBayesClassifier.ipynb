# %% [markdown]
# <a href="https://colab.research.google.com/github/VisithraRavichandran/HALIFA/blob/SDLC/NavieBayesClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-1b38672b-45d9-4ed3-ac86-20a3fa984359" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b38672b-45d9-4ed3-ac86-20a3fa984359">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('pacific.csv')
data
# Out:
#              ID                 Name      Date  Time Event Status Latitude  \
# 0      EP011949              UNNAMED  19490611     0           TS    20.2N
# 1      EP011949              UNNAMED  19490611   600           TS    20.2N
# 2      EP011949              UNNAMED  19490611  1200           TS    20.2N
# 3      EP011949              UNNAMED  19490611  1800           TS    20.3N
# 4      EP011949              UNNAMED  19490612     0           TS    20.4N
# ...         ...                  ...       ...   ...   ...    ...      ...
# 26132  EP222015               SANDRA  20151128  1200           LO    21.7N
# 26133  EP222015               SANDRA  20151128  1800           LO    22.4N
# 26134  EP222015               SANDRA  20151129     0           LO    23.1N
# 26135  EP222015               SANDRA  20151129   600           LO    23.5N
# 26136  EP222015               SANDRA  20151129  1200           LO    24.2N
#
#       Longitude  Maximum Wind  Minimum Pressure  ...  Low Wind SW  \
# ...

# %%
pre_columns=data[:]
pre_columns.drop(['ID','Name','Date','Status','Time','Event','Latitude','Longitude'],axis=1,inplace=True)
pre_columns
# Out:
# /tmp/ipykernel_1797/2388353499.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pre_columns.drop(['ID','Name','Date','Status','Time','Event','Latitude','Longitude'],axis=1,inplace=True)
#        Maximum Wind  Minimum Pressure  Low Wind NE  Low Wind SE  Low Wind SW  \
# 0                45              -999         -999         -999         -999
# 1                45              -999         -999         -999         -999
# 2                45              -999         -999         -999         -999
# 3                45              -999         -999         -999         -999
# 4                45              -999         -999         -999         -999
# ...             ...               ...          ...          ...          ...
# ...

# %%
relevant_cols=pre_columns.columns
relevant_cols
# Out:
# Index(['Status', 'Maximum Wind', 'Minimum Pressure', 'Low Wind NE',
#        'Low Wind SE', 'Low Wind SW', 'Low Wind NW', 'Moderate Wind NE',
#        'Moderate Wind SE', 'Moderate Wind SW', 'Moderate Wind NW',
#        'High Wind NE', 'High Wind SE', 'High Wind SW', 'High Wind NW'],
#       dtype='object')

# %%
train,test=train_test_split(data,test_size=0.2)
train_X=train[relevant_cols]
train_Y=train['Status']
test_X=test[relevant_cols]
test_Y=test['Status']

# %%
#Use Model
gnb=GaussianNB()

# %%
pd.DataFrame({'Actual':test_Y,'Predicted':predicated_gnb})
# Out:
#       Actual Predicted
# 10088     TS        ET
# 25587     LO        DB
# 6683      HU        DB
# 18399     TD        ET
# 9016      TD        ET
# ...      ...       ...
# 2036      TS        ET
# 23431     TD        ET
# 6225      TS        ET
# 12185     TD        ET
# 2654      TS        DB
#
# [5228 rows x 2 columns]
